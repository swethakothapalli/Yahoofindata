# %%
import yfinance as yahooFinance
import pandas as pd
import datetime
# Out:
# /Users/swetha/Desktop/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
#Expoting historical yahoo financial data for single csv file
startDate = datetime.datetime(2019, 5, 31)
endDate = datetime.datetime(2021, 1, 30)

data = yahooFinance.Ticker("BMY")
 
# Valid options are period = 1d, 5d, 1mo, 3mo, 6mo, 1y,
# 2y, 5y, 10y and ytd.
findata = data.history(start=startDate,end=endDate)
findata.to_csv(r'/Users/swetha/Documents/fin_data/BMY.csv')

# %%
# Exporting historical yahoo financial data saving it individually with its ticker name in csv files
df = pd.read_csv(r"/Users/swetha/Downloads/Biofin programs/symbols_valid_meta.csv")
comp = df["Symbol"]
startDate = datetime.datetime(2019, 5, 31)
endDate = datetime.datetime(2021, 1, 30)

#print(comp)
for i in comp:
    try:
        data = yahooFinance.Ticker("{}".format(i))
     
    # Valid options are period = 1d, 5d, 1mo, 3mo, 6mo, 1y,
    # 2y, 5y, 10y and ytd.
        findata = data.history(start=startDate,end=endDate)
        #print (findata)
        findata.to_csv(r'/Users/swetha/Documents/fin_data/{}.csv'.format(i))
    except:
        print(ticker)
# Out:
# AAMC: Data doesn't exist for startDate = 1559275200, endDate = 1611982800
# AAWW: No timezone found, symbol may be delisted
# AAXN: No timezone found, symbol may be delisted
# ABB: No timezone found, symbol may be delisted
# ABC: No timezone found, symbol may be delisted
# ABTX: No timezone found, symbol may be delisted
# ACAM: No timezone found, symbol may be delisted
# ACAMU: No timezone found, symbol may be delisted
# ACBI: No timezone found, symbol may be delisted
# ACC: No timezone found, symbol may be delisted
# ACER: No timezone found, symbol may be delisted
# ACGLP: No timezone found, symbol may be delisted
# ACH: No timezone found, symbol may be delisted
# ACIA: No timezone found, symbol may be delisted
# ACRX: No timezone found, symbol may be delisted
# ACT: Data doesn't exist for startDate = 1559275200, endDate = 1611982800
# ACTT: No timezone found, symbol may be delisted
# ACTTU: No timezone found, symbol may be delisted
# ACY: No timezone found, symbol may be delisted
# ...

# %%
#Exporting whole historical financial data to a single master data
df = pd.read_excel(r"/Users/swetha/Downloads/sample_ticker.xlsx")
comp = df["Symbol"]
startDate = datetime.datetime(2019, 5, 31)
endDate = datetime.datetime(2021, 1, 30)
result = pd.DataFrame()
#print(comp)
for i in comp:

    data = yahooFinance.Ticker("{}".format(i))
     
    # Valid options are period = 1d, 5d, 1mo, 3mo, 6mo, 1y,
    # 2y, 5y, 10y and ytd.
    findata = data.history(start=startDate,end=endDate)
    #print (findata)
    findata['Ticker'] = i
    result = result._append(findata)   
    #print(result) 
result.to_csv(r'/Users/swetha/Documents/fin_data/master.csv')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-05-31 00:00:00-04:00   42.577435   43.002656   42.277852   42.297180
# 2019-06-03 00:00:00-04:00   42.425233   42.985747   41.137496   41.869549
# 2019-06-04 00:00:00-04:00   42.386584   43.447215   42.164311   43.401310
# 2019-06-05 00:00:00-04:00   44.522336   44.693875   43.763707   44.101948
# 2019-06-06 00:00:00-04:00   44.232416   44.809843   44.007724   44.749443
# ...                               ...         ...         ...         ...
# 2021-01-25 00:00:00-05:00  140.407930  142.390333  133.999418  140.260712
# 2021-01-26 00:00:00-05:00  140.928077  141.615049  138.739559  140.496262
# 2021-01-27 00:00:00-05:00  140.761252  141.615075  137.797455  139.416748
# 2021-01-28 00:00:00-05:00  136.923993  139.348036  134.156457  134.539200
# 2021-01-29 00:00:00-05:00  133.302625  134.195696  127.787201  129.504639
#
#                               Volume  Dividends  Stock Splits Ticker
# ...
